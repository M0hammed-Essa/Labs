# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a binary image with shapes and noise
image = np.zeros((200, 600), dtype=np.uint8)
cv2.circle(image, (100, 100), 40, 255, -1)  # Solid circle
cv2.rectangle(image, (200, 60), (280, 140), 255, -1)  # Solid rectangle
cv2.circle(image, (400, 100), 40, 255, 2)  # Hollow circle
cv2.rectangle(image, (500, 60), (580, 140), 255, 2)  # Hollow rectangle

# Add small noise
np.random.seed(0)
for _ in range(1000):
    x, y = np.random.randint(0, 600), np.random.randint(0, 200)
    image[y, x] = 255

# %%
kernel = np.ones((5, 5), np.uint8)

# %%
# Task 1: 

erosion = cv2.erode(image, kernel, iterations=1)
dilation = cv2.dilate(image, kernel, iterations=1)
opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

plt.figure(figsize=(10, 15))

plt.subplot(5, 1, 1)
plt.imshow(image, cmap='gray')
plt.title('Original')
           
plt.subplot(5, 1, 2)
plt.imshow(erosion, cmap='gray')
plt.title('Erosion')
           
plt.subplot(5, 1, 3)
plt.imshow(dilation, cmap='gray')
plt.title('Dilation')
           
plt.subplot(5, 1, 4)
plt.imshow(opening, cmap='gray')
plt.title('Opening')
           
plt.subplot(5, 1, 5)
plt.imshow(closing, cmap='gray')
plt.title('Closing')

plt.tight_layout()
plt.show()

# %%
# Task 2

def circular_structuring_element(radius):
    size = 2 * radius + 1
    kernel = np.zeros((size, size), dtype=np.uint8)
    cv2.circle(kernel, (radius, radius), radius, 1, -1)
    return kernel

radius = 5
circle_kernel = circular_structuring_element(radius)

erosion  = cv2.erode(image, circle_kernel, iterations=1)
dilation = cv2.dilate(image, circle_kernel, iterations=1)
opening  = cv2.morphologyEx(image, cv2.MORPH_OPEN, circle_kernel)
closing  = cv2.morphologyEx(image, cv2.MORPH_CLOSE, circle_kernel)


plt.figure(figsize=(10, 15))

plt.subplot(5, 1, 1)
plt.imshow(image, cmap='gray')
plt.title('Original')
           
plt.subplot(5, 1, 2)
plt.imshow(erosion, cmap='gray')
plt.title('Erosion')
           
plt.subplot(5, 1, 3)
plt.imshow(dilation, cmap='gray')
plt.title('Dilation')
           
plt.subplot(5, 1, 4)
plt.imshow(opening, cmap='gray')
plt.title('Opening')
           
plt.subplot(5, 1, 5)
plt.imshow(closing, cmap='gray')
plt.title('Closing')

plt.tight_layout()
plt.show()
